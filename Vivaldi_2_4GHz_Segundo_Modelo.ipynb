# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoNestasio/Antena-Vivaldi/blob/acostada/Vivaldi_2_4GHz_Segundo_Modelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **2.4Ghz**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Ruta del archivo Excel
ruta_csv = '/content/Pol. Principal - Diagrama de radiación-corrected.csv'

# Importar datos desde Excel a un DataFrame de pandas
datos = pd.read_csv(ruta_csv)
datos['Positions'] = datos['Positions'].str.replace('deg', '').astype(float)
datos['Amplitudes'] = datos['Amplitudes'].str.replace('dB', '').astype(float)

# Ver los primeros registros para asegurarte de que los datos se importaron correctamente
print(datos.head())
print(datos.columns)

# Acceder a los datos de las columnas
angulos = np.deg2rad(datos['Positions'])
amplitudes = datos['Amplitudes']


# Encontrar el punto máximo
maximo_idx = np.argmax(amplitudes)
angulo_max = angulos[maximo_idx]
amplitud_max = amplitudes[maximo_idx]

# Crear el gráfico
plt.figure()
plt.polar(angulos, amplitudes, marker='o', markersize=1, label='Radiación')
plt.polar(0, amplitud_max, 'ro', label='Máximo')
plt.title('Diagrama de Radiación Medición (dB)')
plt.legend()
plt.ylim(-15, 15)
plt.yticks(np.arange(-15, 16, 5))
plt.show()
print('Máximo:',amplitud_max)
# Out:
#    Unnamed: 0  Positions  Amplitudes
# 0           0      360.0    7.986293
# 1           1      360.0    7.957293
# 2           2      360.0    7.957293
# 3           3      359.9    8.013293
# 4           4      359.9    7.995293
# Index(['Unnamed: 0', 'Positions', 'Amplitudes'], dtype='object')
# Máximo: 8.01329317328915

# %%
# Gràfico (Simulación)
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Ruta del archivo Excel
ruta_csv4 = '/content/Gain Plot 2-4 GHz_ComparacionMedicion.csv'

# Importar datos desde Excel a un DataFrame de pandas
datos4 = pd.read_csv(ruta_csv4)
# Ver los primeros registros para asegurarte de que los datos se importaron correctamente
print(datos4.head())
print(datos4.columns)

# Acceder a los datos de las columnas
angulos4 = np.deg2rad(datos4['Theta [deg]']-90)
amplitudes4 = datos4["dB(RealizedGainTotal) [] - Freq='2.4GHz' Theta='90.0000000000002deg'"]


# Encontrar el punto máximo
maximo_idx4 = np.argmax(amplitudes4)
angulo_max4 = angulos4[maximo_idx4]
amplitud_max4 = amplitudes4[maximo_idx4]
dif_max=amplitud_max4-amplitud_max

# Crear el gráfico
plt.figure(figsize=(10, 10))
plt.polar(angulos4, amplitudes4, marker='o', markersize=0, label='Simulación')
plt.polar(angulo_max4, amplitud_max4, 'ro', label='Máximo')
plt.polar(angulos, amplitudes, marker='o', markersize=1, label='Medición')
plt.polar(0, amplitud_max, 'go', label='Máximo')
plt.title('Diagrama de Radiación Simulación(dB)')
plt.legend()
plt.ylim(-15, 18)  # Por ejemplo, establece el mínimo en 0 y el máximo en 20 dB
plt.yticks(np.arange(-15  , 10, 5))
plt.show()
plt.show()
print('Máximo Simulado:',amplitud_max4 )
print('Máximo Medido:',amplitud_max )
print('Diferencia:', dif_max)
# Out:
#    Theta [deg]  \
# 0            0
# 1            2
# 2            4
# 3            6
# 4            8
#
#    dB(RealizedGainTotal) [] - Freq='2.4GHz' Phi='90.0000000000002deg'  \
# 0                                          -5.294055
# 1                                          -4.903697
# 2                                          -4.345844
# 3                                          -3.664205
# 4                                          -2.907030
#
#    dB(RealizedGainTotal) [] - Freq='2.45GHz' Phi='90.0000000000002deg'  \
# 0                                          -5.321047
# 1                                          -5.129024
# 2                                          -4.712810
# 3                                          -4.105580
# 4                                          -3.363918
#
#    dB(RealizedGainTotal) [] - Freq='2.5GHz' Phi='90.0000000000002deg'  \
# 0                                          -5.208704
# 1                                          -5.240425
# 2                                          -5.010745
# 3                                          -4.522609
# 4                                          -3.828204
#
#    dB(RealizedGainTotal) [] - Freq='2.4GHz' Theta='90.0000000000002deg'  \
# 0                                         -10.704642
# 1                                         -10.081512
# 2                                          -9.397025
# 3                                          -8.687056
# 4                                          -7.977879
#
#    dB(RealizedGainTotal) [] - Freq='2.45GHz' Theta='90.0000000000002deg'  \
# 0                                         -11.767012
# 1                                         -11.196382
# 2                                         -10.548534
# 3                                          -9.854823
# 4                                          -9.141978
#
#    dB(RealizedGainTotal) [] - Freq='2.5GHz' Theta='90.0000000000002deg'
# 0                                         -12.917787
# 1                                         -12.436126
# 2                                         -11.863123
# 3                                         -11.218900
# 4                                         -10.526421
# Index(['Theta [deg]',
#        'dB(RealizedGainTotal) [] - Freq='2.4GHz' Phi='90.0000000000002deg'',
#        'dB(RealizedGainTotal) [] - Freq='2.45GHz' Phi='90.0000000000002deg'',
#        'dB(RealizedGainTotal) [] - Freq='2.5GHz' Phi='90.0000000000002deg'',
#        'dB(RealizedGainTotal) [] - Freq='2.4GHz' Theta='90.0000000000002deg'',
#        'dB(RealizedGainTotal) [] - Freq='2.45GHz' Theta='90.0000000000002deg'',
#        'dB(RealizedGainTotal) [] - Freq='2.5GHz' Theta='90.0000000000002deg''],
#       dtype='object')
# Máximo Simulado: 8.07511743510406
# Máximo Medido: 8.01329317328915
# Diferencia: 0.06182426181491074
